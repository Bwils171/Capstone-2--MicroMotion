# %%
#import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#import pyarrow.feather as feather 
#I can't get this to work in the environment kernel but it works in the base environment kernel
#it kills the kernel when trying to import. I am using same version of pyarrow and when i created a copy of the base 
#environment it works from there, but not if I build from scratch

# %% [markdown]
# # Demographic Data
# ### Load data from demographic file

# %%
#import demographic data that is held in single csv. includes general info about participants, and answers to provided questionaire.
demo_file = r'Source_Data\Micro_Motion_2012\demographics\self_reportNM12.csv'
demographics = pd.read_csv(demo_file)

# %% [markdown]
# ### Investigate demographic information

# %%
demographics.head()
# Out:
#   Group  Subject  Age Sex  Height (m)  Music listening hours/week  \
# 0     A        1   23   M        1.72                           5
# 1     A        2   24   M        1.67                          10
# 2     A        3   27   F        1.63                          14
# 3     A        4   27   M        1.75                           5
# 4     A        9   24   F        1.64                          15
#
#    Perform/produce/compose music hours/week  Dance hours/week  \
# 0                                      30.0               1.0
# 1                                      10.0               2.0
# 2                                       1.0               4.0
# 3                                      20.0               2.0
# 4                                       0.0               2.0
#
#    Exercise (no dance) hours/week  Tiresome experience (1-5)  \
# 0                             7.0                          3
# 1                            10.0                          1
# 2                             3.0                          4
# 3                             2.0                          4
# 4                             6.0                          2
#
#    Experience of motion (1-5)  Experience of moving more to music (1-5)  \
# 0                         3.0                                         2
# 1                         2.0                                         2
# 2                         3.0                                         4
# 3                         5.0                                         3
# 4                         2.0                                         1
#
#    Eyes open?  Locked knees?   Mean QoM  Mean QoM w/oM  Mean QoM w M  \
# 0         1.0            1.0   8.271082       7.955534      8.586613
# 1         1.0            1.0  11.224096      10.627763     11.820396
# 2         0.0            0.5   6.441350       6.063694      6.818985
# 3         1.0            1.0   5.216179       5.289182      5.143181
# 4         1.0            1.0   5.151870       4.940202      5.363525
#
#    NoMus-Mus Diff
# 0        0.631079
# 1        1.192633
# 2        0.755291
# 3       -0.146001
# 4        0.423323

# %%
demographics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91 entries, 0 to 90
# Data columns (total 18 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Group                                     91 non-null     object
#  1   Subject                                   91 non-null     int64
#  2   Age                                       91 non-null     int64
#  3   Sex                                       90 non-null     object
#  4   Height (m)                                91 non-null     float64
#  5   Music listening hours/week                91 non-null     int64
#  6   Perform/produce/compose music hours/week  91 non-null     float64
#  7   Dance hours/week                          91 non-null     float64
#  8   Exercise (no dance) hours/week            91 non-null     float64
#  9   Tiresome experience (1-5)                 91 non-null     int64
#  10  Experience of motion (1-5)                90 non-null     float64
#  11  Experience of moving more to music (1-5)  91 non-null     int64
#  12  Eyes open?                                74 non-null     float64
#  13  Locked knees?                             74 non-null     float64
#  14  Mean QoM                                  91 non-null     float64
#  15  Mean QoM w/oM                             91 non-null     float64
#  16  Mean QoM w M                              91 non-null     float64
#  17  NoMus-Mus Diff                            91 non-null     float64
# dtypes: float64(11), int64(5), object(2)
# memory usage: 12.9+ KB

# %% [markdown]
# ### Remove and/or modify NaN values

# %%
demographics[demographics['Eyes open?'].isnull()]
# Out:
#    Group  Subject  Age Sex  Height (m)  Music listening hours/week  \
# 74     P        1   24   M        1.72                          35
# 75     P        2   23   F        1.64                           6
# 76     P        3   51   F        1.52                          10
# 77     P        4   24   F        1.73                           3
# 78     P        5   21   M        1.76                           3
# 79     P        6   36   F        1.61                           4
# 80     P        7   24   M        1.73                           3
# 81     P        8   24   F        1.71                          30
# 82     P        9   22   F        1.66                          20
# 83     P       10   22   M        1.89                           7
# 84     P       11   27   F        1.61                          20
# 85     P       12   27   M        1.84                          10
# 86     P       13   31   F        1.59                          24
# 87     P       14   23   F        1.62                          22
# 88     P       15   38   M        1.80                          20
# 89     P       16   22   M        1.69                           3
# 90     P       17   24   M        1.67                          16
#
#     Perform/produce/compose music hours/week  Dance hours/week  \
# 74                                      40.0               0.0
# 75                                       3.0               2.0
# 76                                      10.0               0.0
# 77                                       0.0               1.0
# 78                                      10.0               0.5
# 79                                       2.0               0.0
# 80                                       3.0               0.5
# 81                                      30.0               4.0
# 82                                       6.0               3.0
# 83                                       7.0               0.0
# 84                                      14.0               4.0
# 85                                      10.0               2.0
# 86                                       2.0               1.0
# 87                                       6.0               3.0
# 88                                      30.0               0.0
# 89                                      40.0               1.0
# 90                                      14.0               3.5
#
#     Exercise (no dance) hours/week  Tiresome experience (1-5)  \
# 74                             1.0                          2
# 75                             4.0                          3
# 76                             0.5                          1
# 77                             0.5                          3
# 78                             3.0                          2
# 79                             0.0                          5
# 80                             0.5                          4
# 81                             4.0                          3
# 82                             1.0                          2
# 83                             4.5                          5
# 84                             2.0                          1
# 85                             1.0                          5
# 86                             2.0                          2
# 87                             3.5                          2
# 88                             2.0                          3
# 89                             3.0                          2
# 90                             1.0                          1
#
#     Experience of motion (1-5)  Experience of moving more to music (1-5)  \
# 74                         4.0                                         3
# 75                         4.0                                         3
# 76                         2.0                                         2
# 77                         4.0                                         3
# 78                         3.0                                         2
# 79                         4.0                                         4
# 80                         3.0                                         2
# 81                         2.0                                         4
# 82                         3.0                                         2
# 83                         3.0                                         1
# 84                         4.0                                         3
# 85                         3.0                                         5
# 86                         3.0                                         4
# 87                         2.0                                         2
# 88                         2.0                                         2
# 89                         3.0                                         2
# 90                         3.0                                         4
#
#     Eyes open?  Locked knees?   Mean QoM  Mean QoM w/oM  Mean QoM w M  \
# 74         NaN            NaN   9.022333       8.926027      9.118634
# 75         NaN            NaN   5.662621       5.854347      5.470907
# 76         NaN            NaN   4.594001       4.438988      4.749006
# 77         NaN            NaN   7.740670       7.749527      7.731813
# 78         NaN            NaN   7.140620       7.147052      7.134189
# 79         NaN            NaN   4.301132       4.151781      4.450474
# 80         NaN            NaN   5.890001       5.723056      6.056937
# 81         NaN            NaN   6.004398       6.105638      5.903164
# 82         NaN            NaN   5.059475       5.106874      5.012078
# 83         NaN            NaN  10.248176       9.667558     10.828762
# 84         NaN            NaN   6.181310       6.335987      6.026642
# 85         NaN            NaN  13.699610       9.083332     18.315629
# 86         NaN            NaN   4.643596       4.633447      4.653745
# 87         NaN            NaN   6.929825       7.152168      6.707495
# 88         NaN            NaN   4.231206       4.234687      4.227725
# 89         NaN            NaN   6.500170       6.310397      6.689931
# 90         NaN            NaN   5.467223       5.047627      5.886797
#
#     NoMus-Mus Diff
# 74        0.192607
# 75       -0.383440
# 76        0.310018
# 77       -0.017714
# 78       -0.012864
# 79        0.298692
# 80        0.333881
# 81       -0.202474
# 82       -0.094797
# 83        1.161204
# 84       -0.309345
# 85        9.232296
# 86        0.020298
# 87       -0.444673
# 88       -0.006963
# 89        0.379534
# 90        0.839170

# %% [markdown]
# The data seems relatively clean. most columns are numeric type with the exception of Group and Sex. There is one participant who didn't provide Sex info, we can drop this row without considerable affect to data. There are 17 participants who have no value for 'Eyes open?' and 'Locked knees'. This happened for all participants in the P group. For now we will enter 0.5 which represents both for both of these columns. If these two columns are found to be strong indicators of movement we can revisit this decision and review it affect more closely. There is also one participant who didn't give an experience of motion answer, we will use a mean of the column to fill.

# %%
#Fill NaN values under 'Eyes open?' and 'Locked knees' with 0.5
demographics['Eyes open?'].fillna(0.5, inplace=True)
demographics['Locked knees?'].fillna(0.5, inplace=True)
print(demographics[demographics['Group']=='P'].T)
# Out:
#                                                 74        75        76  \
# Group                                            P         P         P
# Subject                                          1         2         3
# Age                                             24        23        51
# Sex                                              M         F         F
# Height (m)                                    1.72      1.64      1.52
# Music listening hours/week                      35         6        10
# Perform/produce/compose music hours/week      40.0       3.0      10.0
# Dance hours/week                               0.0       2.0       0.0
# Exercise (no dance) hours/week                 1.0       4.0       0.5
# Tiresome experience (1-5)                        2         3         1
# Experience of motion (1-5)                     4.0       4.0       2.0
# Experience of moving more to music (1-5)         3         3         2
# Eyes open?                                     0.5       0.5       0.5
# Locked knees?                                  0.5       0.5       0.5
# Mean QoM                                  9.022333  5.662621  4.594001
# Mean QoM w/oM                             8.926027  5.854347  4.438988
# Mean QoM w M                              9.118634  5.470907  4.749006
# NoMus-Mus Diff                            0.192607  -0.38344  0.310018
#
#                                                 77        78        79  \
# Group                                            P         P         P
# Subject                                          4         5         6
# Age                                             24        21        36
# Sex                                              F         M         F
# Height (m)                                    1.73      1.76      1.61
# Music listening hours/week                       3         3         4
# Perform/produce/compose music hours/week       0.0      10.0       2.0
# Dance hours/week                               1.0       0.5       0.0
# Exercise (no dance) hours/week                 0.5       3.0       0.0
# Tiresome experience (1-5)                        3         2         5
# Experience of motion (1-5)                     4.0       3.0       4.0
# Experience of moving more to music (1-5)         3         2         4
# Eyes open?                                     0.5       0.5       0.5
# Locked knees?                                  0.5       0.5       0.5
# Mean QoM                                   7.74067   7.14062  4.301132
# Mean QoM w/oM                             7.749527  7.147052  4.151781
# Mean QoM w M                              7.731813  7.134189  4.450474
# NoMus-Mus Diff                           -0.017714 -0.012864  0.298692
#
#                                                 80        81        82  \
# Group                                            P         P         P
# Subject                                          7         8         9
# Age                                             24        24        22
# Sex                                              M         F         F
# Height (m)                                    1.73      1.71      1.66
# Music listening hours/week                       3        30        20
# Perform/produce/compose music hours/week       3.0      30.0       6.0
# Dance hours/week                               0.5       4.0       3.0
# Exercise (no dance) hours/week                 0.5       4.0       1.0
# Tiresome experience (1-5)                        4         3         2
# Experience of motion (1-5)                     3.0       2.0       3.0
# Experience of moving more to music (1-5)         2         4         2
# Eyes open?                                     0.5       0.5       0.5
# Locked knees?                                  0.5       0.5       0.5
# Mean QoM                                  5.890001  6.004398  5.059475
# Mean QoM w/oM                             5.723056  6.105638  5.106874
# Mean QoM w M                              6.056937  5.903164  5.012078
# NoMus-Mus Diff                            0.333881 -0.202474 -0.094797
#
#                                                  83        84         85  \
# Group                                             P         P          P
# Subject                                          10        11         12
# Age                                              22        27         27
# Sex                                               M         F          M
# Height (m)                                     1.89      1.61       1.84
# Music listening hours/week                        7        20         10
# Perform/produce/compose music hours/week        7.0      14.0       10.0
# Dance hours/week                                0.0       4.0        2.0
# Exercise (no dance) hours/week                  4.5       2.0        1.0
# Tiresome experience (1-5)                         5         1          5
# Experience of motion (1-5)                      3.0       4.0        3.0
# Experience of moving more to music (1-5)          1         3          5
# Eyes open?                                      0.5       0.5        0.5
# Locked knees?                                   0.5       0.5        0.5
# Mean QoM                                  10.248176   6.18131   13.69961
# Mean QoM w/oM                              9.667558  6.335987   9.083332
# Mean QoM w M                              10.828762  6.026642  18.315629
# NoMus-Mus Diff                             1.161204 -0.309345   9.232296
#
#                                                 86        87        88  \
# Group                                            P         P         P
# Subject                                         13        14        15
# Age                                             31        23        38
# Sex                                              F         F         M
# Height (m)                                    1.59      1.62       1.8
# Music listening hours/week                      24        22        20
# Perform/produce/compose music hours/week       2.0       6.0      30.0
# Dance hours/week                               1.0       3.0       0.0
# Exercise (no dance) hours/week                 2.0       3.5       2.0
# Tiresome experience (1-5)                        2         2         3
# Experience of motion (1-5)                     3.0       2.0       2.0
# Experience of moving more to music (1-5)         4         2         2
# Eyes open?                                     0.5       0.5       0.5
# Locked knees?                                  0.5       0.5       0.5
# Mean QoM                                  4.643596  6.929825  4.231206
# Mean QoM w/oM                             4.633447  7.152168  4.234687
# Mean QoM w M                              4.653745  6.707495  4.227725
# NoMus-Mus Diff                            0.020298 -0.444673 -0.006963
#
#                                                 89        90
# Group                                            P         P
# Subject                                         16        17
# Age                                             22        24
# Sex                                              M         M
# Height (m)                                    1.69      1.67
# Music listening hours/week                       3        16
# Perform/produce/compose music hours/week      40.0      14.0
# Dance hours/week                               1.0       3.5
# Exercise (no dance) hours/week                 3.0       1.0
# Tiresome experience (1-5)                        2         1
# Experience of motion (1-5)                     3.0       3.0
# Experience of moving more to music (1-5)         2         4
# Eyes open?                                     0.5       0.5
# Locked knees?                                  0.5       0.5
# Mean QoM                                   6.50017  5.467223
# Mean QoM w/oM                             6.310397  5.047627
# Mean QoM w M                              6.689931  5.886797
# NoMus-Mus Diff                            0.379534   0.83917

# %% [markdown]
# The column names are rather long. We are going to replace some of them them with shorter versions.

# %%
#rename columns with shorter names
new_columns = {'Height (m)':'Height',
               'Music listening hours/week':'Listen', 
               'Perform/produce/compose music hours/week':'Produce', 
               'Dance hours/week':'Dance', 
               'Exercise (no dance) hours/week':'Exercise', 
               'Tiresome experience (1-5)':'Tiresome', 
               'Experience of motion (1-5)':'Exper_silent', 
               'Experience of moving more to music (1-5)':'Exper_music', 
               'Eyes open?':'Eyes', 
               'Locked knees?':'Knees'}
demos = demographics.rename(columns=new_columns)

# %%
#drop row with NaN in sex column
#print(demos.shape)
#demos.dropna(subset=['Sex'], inplace=True)
#print(demos.shape)

# %%
#Fill single datapoint in Exper_silent with mean from column
demos['Exper_silent'].fillna(demos['Exper_silent'].mean(), inplace=True)
print(demos.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91 entries, 0 to 90
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Group           91 non-null     object
#  1   Subject         91 non-null     int64
#  2   Age             91 non-null     int64
#  3   Sex             90 non-null     object
#  4   Height          91 non-null     float64
#  5   Listen          91 non-null     int64
#  6   Produce         91 non-null     float64
#  7   Dance           91 non-null     float64
#  8   Exercise        91 non-null     float64
#  9   Tiresome        91 non-null     int64
#  10  Exper_silent    91 non-null     float64
#  11  Exper_music     91 non-null     int64
#  12  Eyes            91 non-null     float64
#  13  Knees           91 non-null     float64
#  14  Mean QoM        91 non-null     float64
#  15  Mean QoM w/oM   91 non-null     float64
#  16  Mean QoM w M    91 non-null     float64
#  17  NoMus-Mus Diff  91 non-null     float64
# dtypes: float64(11), int64(5), object(2)
# memory usage: 12.9+ KB
# None

# %% [markdown]
# ### Create global participant ID column
# It will be simpler to have a single column to note individual participants instead of two ,'Group' and 'Subject'. As all grouping are undertood to have had the same experience and not affected each other, we will create a new column that simply numbers particpants 1 to 90. This will also remove any confusion about the few particpants who didn't provide a survey and missing numbers within groups. We will need to perform the same column addition to the motion data in order to properly line them up and will leave the 'Group' and 'Subject' columns in place for now incase they are usful for combining on.

# %%
#add column for Participant ID, PID
demos['PID']=list(range (1,92))
demos.head()
# Out:
#   Group  Subject  Age Sex  Height  Listen  Produce  Dance  Exercise  Tiresome  \
# 0     A        1   23   M    1.72       5     30.0    1.0       7.0         3
# 1     A        2   24   M    1.67      10     10.0    2.0      10.0         1
# 2     A        3   27   F    1.63      14      1.0    4.0       3.0         4
# 3     A        4   27   M    1.75       5     20.0    2.0       2.0         4
# 4     A        9   24   F    1.64      15      0.0    2.0       6.0         2
#
#    Exper_silent  Exper_music  Eyes  Knees   Mean QoM  Mean QoM w/oM  \
# 0           3.0            2   1.0    1.0   8.271082       7.955534
# 1           2.0            2   1.0    1.0  11.224096      10.627763
# 2           3.0            4   0.0    0.5   6.441350       6.063694
# 3           5.0            3   1.0    1.0   5.216179       5.289182
# 4           2.0            1   1.0    1.0   5.151870       4.940202
#
#    Mean QoM w M  NoMus-Mus Diff  PID
# 0      8.586613        0.631079    1
# 1     11.820396        1.192633    2
# 2      6.818985        0.755291    3
# 3      5.143181       -0.146001    4
# 4      5.363525        0.423323    5

# %%
demos['Group'].unique()
# Out:
# array(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'P'], dtype=object)

# %%
#export demographic dataframe (commented out so as to not overwrite without intention)
demos.to_pickle('DFs/demos_clean.pkl')

# %% [markdown]
# Note that group b subject 3 has NaN under 'Sex'. This was left in to simplify the PID import sequence. There are two total PID's with NaN in teh 'Sex' column and we will eliminate them prior to entering into model. If 'Sex' turns out to be a minimally dependant variable then we will add back in using M for one and F for the other in order to gain their motion data, otherwise they will just be dropped if 'Sex' is a strong variable as we don't want to sway the model with incorrect data.

# %% [markdown]
# # Summary
# The data for both demographics was read in and combine so that we can view individual participant demopgrahic data with their motion data. The sound data is the next step bring in clean as needed. The EDA and feature engineering process will proceed with a single participant at first and then expanded to other participants.
